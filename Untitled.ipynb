# %%
# !python3 deeppm_act.py helpdesk.csv ACT nn_helpdesk_INC.log
# Out:
# Num cases:  3805
# Num sequences: 9906
# Activities:  {'9', '6', '3', '2', '1', '5', '8', '7', '4'}
# Classes:  (array([0, 1, 2, 3, 4, 5, 6, 7]), array([ 961, 4148,   44,  500,    5, 4230,    4,   14], dtype=int64))
# Fold 0
# Starting model selection...
#
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# {'batch_size': 9, 'embedding_size': 5, 'input_length': 13, 'learning_rate': 0.001956433080955889, 'model_type': 'ACT', 'n_classes': 8, 'n_modules': 1, 'vocab_size': 9}
#
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# Model: "model"
#
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# __________________________________________________________________________________________________
#
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
# ...
