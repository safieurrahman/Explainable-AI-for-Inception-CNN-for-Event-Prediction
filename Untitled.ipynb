# %%
# !python3 deeppm_act.py helpdesk.csv ACT nn_helpdesk_INC.log
# Out:
# Num cases:  3805
# Num sequences: 9906
# Activities:  {'6', '9', '3', '8', '7', '5', '1', '4', '2'}
# Classes:  (array([0, 1, 2, 3, 4, 5, 6, 7]), array([4148,  961, 4230,    4,    5,  500,   14,   44], dtype=int64))
# Fold 0
# Starting model selection...
#
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# {'batch_size': 9, 'embedding_size': 5, 'input_length': 13, 'learning_rate': 0.001956433080955889, 'model_type': 'ACT', 'n_classes': 8, 'n_modules': 1, 'vocab_size': 9}
# Using TensorFlow backend.
# C:\Python\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ...
